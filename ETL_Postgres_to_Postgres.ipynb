# %%
# pip install  psycopg2
# Out:
# ...
#   Using cached psycopg2-2.8.6-cp38-cp38-win_amd64.whl (1.1 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.3.1; however, version 21.1.2 is available.
# You should consider upgrading via the 'C:\ProgramData\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import psycopg2
import pandas as pd

# %%
# create connections
conn_string= "host='192.168.147.128' port=54320 dbname='my_database' user='root' password='postgres'" 
conn_string2= "host='192.168.147.128' port=5433 dbname='my_database' user='root' password='postgres'"
# Out:
# (1, 'Customer#000000001', 'IVhzIApeRb ot,c,E', 15, '25-989-741-2988', Decimal('711.56'), 'BUILDING  ', 'to the even, regular platelets. regular, ironic epitaphs nag e')

# %%
#create dump files for instance "my_postgres"

with psycopg2.connect(conn_string) as conn, conn.cursor() as cursor:
    q = "COPY customer TO STDOUT WITH DELIMITER ',' CSV HEADER;"
    with open('customer_dump.csv', 'w') as f:
        cursor.copy_expert(q, f)
        
with psycopg2.connect(conn_string) as conn, conn.cursor() as cursor:
    q = "COPY lineitem TO STDOUT WITH DELIMITER ',' CSV HEADER;"
    with open('lineitem_dump.csv', 'w') as f:
        cursor.copy_expert(q, f)
        
with psycopg2.connect(conn_string) as conn, conn.cursor() as cursor:
    q = "COPY nation TO STDOUT WITH DELIMITER ',' CSV HEADER;"
    with open('nation_dump.csv', 'w') as f:
        cursor.copy_expert(q, f)        
        
        
with psycopg2.connect(conn_string) as conn, conn.cursor() as cursor:
    q = "COPY orders TO STDOUT WITH DELIMITER ',' CSV HEADER;"
    with open('orders_dump.csv', 'w') as f:
        cursor.copy_expert(q, f)       
        
with psycopg2.connect(conn_string) as conn, conn.cursor() as cursor:
    q = "COPY part TO STDOUT WITH DELIMITER ',' CSV HEADER;"
    with open('part_dump.csv', 'w') as f:
        cursor.copy_expert(q, f)        
     
        
with psycopg2.connect(conn_string) as conn, conn.cursor() as cursor:
    q = "COPY partsupp TO STDOUT WITH DELIMITER ',' CSV HEADER;"
    with open('partsupp_dump.csv', 'w') as f:
        cursor.copy_expert(q, f)
        
with psycopg2.connect(conn_string) as conn, conn.cursor() as cursor:
    q = "COPY region TO STDOUT WITH DELIMITER ',' CSV HEADER;"
    with open('region_dump.csv', 'w') as f:
        cursor.copy_expert(q, f)
        
        
with psycopg2.connect(conn_string) as conn, conn.cursor() as cursor:
    q = "COPY supplier TO STDOUT WITH DELIMITER ',' CSV HEADER;"
    with open('supplier_dump.csv', 'w') as f:
        cursor.copy_expert(q, f)

# %%
# check if real file exixts and it's structure

pd.read_csv('lineitem_dump.csv')
# Out:
#          l_orderkey  l_partkey  l_suppkey  l_linenumber  l_quantity  \
# 0             15810      73908       8923             4        26.0
# 1             16833     102428       9959             2        43.0
# 2             19972       3145       5646             3         6.0
# 3             20641     104269       1800             2        48.0
# 4             21089     106051       1072             3         7.0
# ...             ...        ...        ...           ...         ...
# 6001210        1927      67893       2906             1         3.0
# 6001211        5699       1884       6885             1        24.0
# 6001212        5764     100625        626             1        28.0
# 6001213        6693      13613       8616             2        17.0
# 6001214       15552     107133       2154             4        11.0
#
#          l_extendedprice  l_discount  l_tax l_returnflag l_linestatus  \
# 0               48929.40        0.00   0.08            A            F
# ...

# %%
# export data to instance "my_postgres2"

with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    q = "COPY customer from STDIN WITH DELIMITER ',' CSV HEADER;"
    with open('customer_dump.csv', 'r') as f:
        cursor.copy_expert(q, f)

# %%
with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    q = "COPY lineitem from STDIN WITH DELIMITER ',' CSV HEADER;"
    with open('lineitem_dump.csv', 'r') as f:
        cursor.copy_expert(q, f)
        
        
with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    q = "COPY nation from STDIN WITH DELIMITER ',' CSV HEADER;"
    with open('nation_dump.csv', 'r') as f:
        cursor.copy_expert(q, f)
        
with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    q = "COPY orders from STDIN WITH DELIMITER ',' CSV HEADER;"
    with open('orders_dump.csv', 'r') as f:
        cursor.copy_expert(q, f)
        
with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    q = "COPY part from STDIN WITH DELIMITER ',' CSV HEADER;"
    with open('part_dump.csv', 'r') as f:
        cursor.copy_expert(q, f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-e39e36ba46a7> in <module>
#      22 with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
#      23     q = "COPY partsupp from STDIN WITH DELIMITER ',' CSV HEADER;"
# ---> 24     with open('partsupp_dump.csv', 'r') as f:
#      25         cursor.copy_expert(q, f)
#      26
#
# FileNotFoundError: [Errno 2] No such file or directory: 'partsupp_dump.csv'

# %%
with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    q = "COPY partsupp from STDIN WITH DELIMITER ',' CSV HEADER;"
    with open('partsupp_dump.csv', 'r') as f:
        cursor.copy_expert(q, f)        
        
with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    q = "COPY region from STDIN WITH DELIMITER ',' CSV HEADER;"
    with open('region_dump.csv', 'r') as f:
        cursor.copy_expert(q, f)        
        
        
with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    q = "COPY supplier from STDIN WITH DELIMITER ',' CSV HEADER;"
    with open('supplier_dump.csv', 'r') as f:
        cursor.copy_expert(q, f)

# %%
#  check second instance

with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    cursor.execute('select count(*) from customer')
    print(cursor.fetchall())
    
    
with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    cursor.execute('select count(*) from lineitem')
    print(cursor.fetchall())
    
    
with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    cursor.execute('select count(*) from nation')
    print(cursor.fetchall())
    
    
with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    cursor.execute('select count(*) from orders')
    print(cursor.fetchall())
    
    
with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    cursor.execute('select count(*) from part')
    print(cursor.fetchall())
    
    
with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    cursor.execute('select count(*) from partsupp')
    print(cursor.fetchall())
    
with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    cursor.execute('select count(*) from region')
    print(cursor.fetchall())
    
    
with psycopg2.connect(conn_string2) as conn, conn.cursor() as cursor:
    cursor.execute('select count(*) from supplier')
    print(cursor.fetchall())
# Out:
# [(150000,)]
# [(6001215,)]
# [(25,)]
# [(1500000,)]
# [(200000,)]
# [(800000,)]
# [(5,)]
# [(10000,)]
